# %% [markdown]
# <a href="https://colab.research.google.com/github/srivasPankhuri/Twitter-Sentiment-Analysis/blob/main/Twitter_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from sklearn.metrics import confusion_matrix, classification_report
import re
import nltk
import string
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading the dataset

# %%
import csv
train_data=pd.read_csv('twitter sentiment.csv',names=["target","id","date","flag","user","text"], encoding="latin-1",error_bad_lines=False)

# %%
train_data.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   target  1600000 non-null  int64
#  1   id      1600000 non-null  int64
#  2   date    1600000 non-null  object
#  3   flag    1600000 non-null  object
#  4   user    1600000 non-null  object
#  5   text    1600000 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 73.2+ MB

# %%
train_data.shape
# Out:
# (1600000, 6)

# %%
train_data.isna().sum()
# Out:
# target    0
# id        0
# date      0
# flag      0
# user      0
# text      0
# dtype: int64

# %%
train_data['target'].value_counts()
# Out:
# 0    800000
# 4    800000
# Name: target, dtype: int64

# %%
train_data['text']=train_data['text'].str.lower()

# %%
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stops = set(stopwords.words('english'))

# %%
def Remove_StopWord(text):
    return " ".join([word for word in str(text).split() if word not in stops])

train_data['text'] = train_data['text'].apply(lambda text: Remove_StopWord(text))

# %%
train_data
# Out:
#          target          id                          date      flag  \
# 0             0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599995       4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999       4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# ...

# %%
train_data["text"] = train_data['text'].str.replace('[^\w\s]','')

# %%
train_data['text'] = train_data['text'].str.replace('[^a-zA-Z\s]', '')

# %%
train_data.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  switchfoot httptwitpiccomyzl  awww thats bumme...
# 1    scotthamilton  upset cant update facebook texting it might cr...
# 2         mattycus  kenichan dived many times ball managed save  r...
# 3          ElleCTF                   whole body feels itchy like fire
# 4           Karoli  nationwideclass no behaving all im mad here ca...

# %%
train_data.tail()
# Out:
#          target          id                          date      flag  \
# 1599995       4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999       4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# 1599995  AmandaMarie1028                   woke up school best feeling ever
# 1599996      TheWDBoards  thewdbcom  cool hear old walt interviews  http...
# 1599997           bpbabe                    ready mojo makeover ask details
# 1599998     tinydiamondz  happy th birthday boo alll time tupac amaru sh...
# 1599999   RyanTrevMorris  happy charitytuesday thenspcc sparkscharity sp...

# %%
train_data['text'] = train_data['text'].str.replace('http\S+|www.\S+', '', case=False)

# %%
train_data.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  switchfoot   a bummer shoulda got david carr t...
# 1    scotthamilton  upset cant update facebook texting it might cr...
# 2         mattycus  kenichan dived many times ball managed save  r...
# 3          ElleCTF                   whole body feels itchy like fire
# 4           Karoli  nationwideclass no behaving all im mad here ca...

# %%
train_data.iloc[106,5]
# Out:
# 'emily glad mommy done training new job misses her '

# %% [markdown]
# Tokenization

# %%
nltk.download('punkt')
train_data['text']=train_data['text'].apply(nltk.word_tokenize)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
train_data.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  [switchfoot, a, bummer, shoulda, got, david, c...
# 1    scotthamilton  [upset, cant, update, facebook, texting, it, m...
# 2         mattycus  [kenichan, dived, many, times, ball, managed, ...
# 3          ElleCTF            [whole, body, feels, itchy, like, fire]
# 4           Karoli  [nationwideclass, no, behaving, all, im, mad, ...

# %% [markdown]
# ###Stemming and Lemmatization

# %% [markdown]
# #####Stemming

# %%
from nltk.stem.porter import PorterStemmer
stemmer=PorterStemmer()

train_data['text']=train_data['text'].apply(lambda words: [stemmer.stem(word) for word in words])

# %%
train_data.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  [switchfoot, a, bummer, shoulda, got, david, c...
# 1    scotthamilton  [upset, cant, updat, facebook, text, it, might...
# 2         mattycus  [kenichan, dive, mani, time, ball, manag, save...
# 3          ElleCTF             [whole, bodi, feel, itchi, like, fire]
# 4           Karoli  [nationwideclass, no, behav, all, im, mad, her...

# %% [markdown]
# ###### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
train_data['text']=train_data['text'].apply(lambda words: [lemmatizer.lemmatize(word) for word in words])

# %%
train_data.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  [switchfoot, a, bummer, shoulda, got, david, c...
# 1    scotthamilton  [upset, cant, updat, facebook, text, it, might...
# 2         mattycus  [kenichan, dive, mani, time, ball, manag, save...
# 3          ElleCTF             [whole, bodi, feel, itchi, like, fire]
# 4           Karoli  [nationwideclass, no, behav, all, im, mad, her...

# %%
train_data['text']=train_data['text'].apply(lambda sent: ' '.join(sent))

# %%
train_data.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  switchfoot a bummer shoulda got david carr thi...
# 1    scotthamilton  upset cant updat facebook text it might cri re...
# 2         mattycus  kenichan dive mani time ball manag save rest g...
# 3          ElleCTF                    whole bodi feel itchi like fire
# 4           Karoli  nationwideclass no behav all im mad here cant ...

# %% [markdown]
# ####Splitting into Train and Test data

# %%
y=train_data['target']
X=train_data['text']

# %%
y
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 1599995    4
# 1599996    4
# 1599997    4
# 1599998    4
# 1599999    4
# Name: target, Length: 1600000, dtype: int64

# %%
X
# Out:
# 0          switchfoot a bummer shoulda got david carr thi...
# 1          upset cant updat facebook text it might cri re...
# 2          kenichan dive mani time ball manag save rest g...
# 3                            whole bodi feel itchi like fire
# 4          nationwideclass no behav all im mad here cant ...
#                                  ...
# 1599995                        woke up school best feel ever
# 1599996               thewdbcom cool hear old walt interview
# 1599997                         readi mojo makeov ask detail
# 1599998    happi th birthday boo alll time tupac amaru sh...
# 1599999    happi charitytuesday thenspcc sparkschar speak...
# Name: text, Length: 1600000, dtype: object

# %% [markdown]
# WordCloud for Positive words

# %%
data_pos = train_data['text'][800000:]
wc = WordCloud(max_words = 1000 , width = 800 , height = 800,
              collocations=False).generate(" ".join(data_pos))
plt.figure(figsize = (10,10))
plt.imshow(wc)

# %% [markdown]
# Wordcloud for negative words

# %%
data_pos = train_data['text'][:800000]
wc = WordCloud(max_words = 1000 , width = 500 , height = 500,
              collocations=False).generate(" ".join(data_pos))
plt.figure(figsize = (10,10))
plt.imshow(wc)

# %% [markdown]
# Input split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test=vectorizer.transform(X_test)

# %%
X_train[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# Model building

# %% [markdown]
# 1)Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logistic_model=LogisticRegression()
logistic_model.fit(X_train,y_train)
pred1=logistic_model.predict(X_test)
print(classification_report(y_test, pred1))
conf_matrix1 = confusion_matrix(y_test, pred1)
print(conf_matrix1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.76      0.77    199581
#            4       0.77      0.80      0.78    200419
#
#     accuracy                           0.78    400000
#    macro avg       0.78      0.78      0.78    400000
# weighted avg       0.78      0.78      0.78    400000
#
# [[151340  48241]
#  [ 40950 159469]]

# %% [markdown]
# 2)Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB
Naive_model=BernoulliNB()
Naive_model.fit(X_train,y_train)
pred2=Naive_model.predict(X_test)
print(classification_report(y_test, pred2))
conf_matrix2 = confusion_matrix(y_test, pred2)
print(conf_matrix2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77    199581
#            4       0.78      0.75      0.76    200419
#
#     accuracy                           0.77    400000
#    macro avg       0.77      0.77      0.77    400000
# weighted avg       0.77      0.77      0.77    400000
#
# [[156506  43075]
#  [ 50090 150329]]

# %% [markdown]
# 3)SVM

# %%
from sklearn.svm import LinearSVC
SVC_model = LinearSVC()
SVC_model.fit(X_train, y_train)
pred3=SVC_model.predict(X_test)
print(classification_report(y_test, pred3))
conf_matrix3 = confusion_matrix(y_test, pred3)
print(conf_matrix3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77    199581
#            4       0.77      0.78      0.77    200419
#
#     accuracy                           0.77    400000
#    macro avg       0.77      0.77      0.77    400000
# weighted avg       0.77      0.77      0.77    400000
#
# [[152128  47453]
#  [ 44319 156100]]
