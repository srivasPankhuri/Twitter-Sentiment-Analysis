# %% [markdown]
# <a href="https://colab.research.google.com/github/srivasPankhuri/Twitter-Sentiment-Analysis/blob/main/Twitter_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import re
import nltk
import string
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading the dataset

# %%
import csv
train_data=pd.read_csv('twitter_Sentiment.csv',names=["target","id","date","flag","user","text"],encoding="latin-1",error_bad_lines=False)

# %%
train_data.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 6 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   target  1048575 non-null  int64
#  1   id      1048575 non-null  int64
#  2   date    1048575 non-null  object
#  3   flag    1048575 non-null  object
#  4   user    1048575 non-null  object
#  5   text    1048575 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 48.0+ MB

# %%
train_data.shape
# Out:
# (1048575, 6)

# %%
train_data.isna().sum()
# Out:
# target    0
# id        0
# date      0
# flag      0
# user      0
# text      0
# dtype: int64

# %%
train_data['target'].value_counts()
# Out:
# 0    799999
# 4    248576
# Name: target, dtype: int64

# %%
train_data['text']=train_data['text'].str.lower()

# %%
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stops = set(stopwords.words('english'))

# %%
def Remove_StopWord(text):
    return " ".join([word for word in str(text).split() if word not in stops])

train_data['text'] = train_data['text'].apply(lambda text: Remove_StopWord(text))

# %%
train_data
# Out:
#          target          id                          date      flag  \
# 0             0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1048570       4  1960186342  Fri May 29 07:33:44 PDT 2009  NO_QUERY
# 1048571       4  1960186409  Fri May 29 07:33:43 PDT 2009  NO_QUERY
# 1048572       4  1960186429  Fri May 29 07:33:44 PDT 2009  NO_QUERY
# 1048573       4  1960186445  Fri May 29 07:33:44 PDT 2009  NO_QUERY
# 1048574       4  1960186607  Fri May 29 07:33:45 PDT 2009  NO_QUERY
#
#                     user                                               text
# 0        _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - awww, t...
# 1          scotthamilton  upset can't update facebook texting it... migh...
# 2               mattycus  @kenichan dived many times ball. managed save ...
# 3                ElleCTF                   whole body feels itchy like fire
# 4                 Karoli  @nationwideclass no, behaving all. i'm mad. he...
# ...                  ...                                                ...
# 1048570  Madelinedugganx                          grandma making dinenr mum
# 1048571     OffRoad_Dude  mid-morning snack time... bowl cheese noodles....
# 1048572         Falchion  @shadela say like terminiator movies. comes li...
# 1048573   jonasobsessedx              @destinyhope92 im great thaanks wbuu?
# 1048574        sugababez                         cant wait til date weekend
#
# [1048575 rows x 6 columns]

# %%
train_data["text"] = train_data['text'].str.replace('[^\w\s]','')

# %%
train_data['text'] = train_data['text'].str.replace('[^a-zA-Z\s]', '')

# %%
train_data.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  switchfoot httptwitpiccomyzl  awww thats bumme...
# 1    scotthamilton  upset cant update facebook texting it might cr...
# 2         mattycus  kenichan dived many times ball managed save  r...
# 3          ElleCTF                   whole body feels itchy like fire
# 4           Karoli  nationwideclass no behaving all im mad here ca...

# %%
train_data.tail()
# Out:
#          target          id                          date      flag  \
# 1048570       4  1960186342  Fri May 29 07:33:44 PDT 2009  NO_QUERY
# 1048571       4  1960186409  Fri May 29 07:33:43 PDT 2009  NO_QUERY
# 1048572       4  1960186429  Fri May 29 07:33:44 PDT 2009  NO_QUERY
# 1048573       4  1960186445  Fri May 29 07:33:44 PDT 2009  NO_QUERY
# 1048574       4  1960186607  Fri May 29 07:33:45 PDT 2009  NO_QUERY
#
#                     user                                               text
# 1048570  Madelinedugganx                          grandma making dinenr mum
# 1048571     OffRoad_Dude      midmorning snack time bowl cheese noodles yum
# 1048572         Falchion  shadela say like terminiator movies comes like...
# 1048573   jonasobsessedx                  destinyhope im great thaanks wbuu
# 1048574        sugababez                         cant wait til date weekend

# %%
train_data['text'] = train_data['text'].str.replace('http\S+|www.\S+', '', case=False)

# %%
train_data.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  switchfoot   a bummer shoulda got david carr t...
# 1    scotthamilton  upset cant update facebook texting it might cr...
# 2         mattycus  kenichan dived many times ball managed save  r...
# 3          ElleCTF                   whole body feels itchy like fire
# 4           Karoli  nationwideclass no behaving all im mad here ca...

# %%
train_data.iloc[106,5]
# Out:
# 'emily glad mommy done training new job misses her '

# %% [markdown]
# Tokenization

# %%
nltk.download('punkt')
train_data['text']=train_data['text'].apply(nltk.word_tokenize)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
train_data.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  [switchfoot, a, bummer, shoulda, got, david, c...
# 1    scotthamilton  [upset, cant, update, facebook, texting, it, m...
# 2         mattycus  [kenichan, dived, many, times, ball, managed, ...
# 3          ElleCTF            [whole, body, feels, itchy, like, fire]
# 4           Karoli  [nationwideclass, no, behaving, all, im, mad, ...

# %% [markdown]
# Stemming and Lemmatization
